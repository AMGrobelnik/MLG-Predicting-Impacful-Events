# %%
import networkx as nx
from deepsnap.hetero_graph import HeteroGraph
import pickle
import numpy as np

# %%
with open('batch_00000.pkl', 'rb') as f:
    graph = pickle.load(f)
    
with open('batch_hg_00000.pkl', 'rb') as f:
    hetero = pickle.load(f)
    
with open('batch_hg_00000_ex.pkl', 'rb') as f:
    hetero_ex = pickle.load(f)

# %%
events = hetero.node_to_graph_mapping['event']

# %%
events2 = hetero_ex.node_to_graph_mapping['event']

# %%
# Out:
# tensor(0) tensor(0)
# tensor(1) tensor(1)
# tensor(2) tensor(2)
# tensor(3) tensor(3)
# tensor(4) tensor(4)
# tensor(5) tensor(5)
# tensor(6) tensor(6)
# tensor(7) tensor(7)
# tensor(148) tensor(90)
# tensor(149) tensor(91)
# tensor(150) tensor(92)
# tensor(151) tensor(93)
# tensor(152) tensor(94)
# tensor(153) tensor(95)
# tensor(154) tensor(96)
# tensor(155) tensor(97)
# tensor(156) tensor(201)
# tensor(157) tensor(202)
# tensor(158) tensor(203)
# tensor(159) tensor(204)
# tensor(160) tensor(205)
# tensor(161) tensor(206)
# tensor(214) tensor(207)
# tensor(215) tensor(208)
# tensor(216) tensor(209)
# tensor(217) tensor(210)
# tensor(218) tensor(211)
# tensor(219) tensor(212)
# tensor(220) tensor(213)
# tensor(221) tensor(214)
# tensor(267) tensor(309)
# tensor(268) tensor(310)
# tensor(270) tensor(312)
# tensor(271) tensor(313)
# tensor(272) tensor(314)
# tensor(273) tensor(315)
# tensor(274) tensor(316)
# tensor(275) tensor(317)
# tensor(276) tensor(318)
# tensor(334) tensor(376)
# ...

# %%
hetero_ex.num_nodes()
# Out:
# {'event': 12826, 'concept': 88490, 'event_target': 256}

# %%
hetero.num_nodes()
# Out:
# {'event': 12826, 'event_target': 256}

# %%
hg = HeteroGraph(graph)

# %%
hetero.node_to_graph_mapping
# Out:
# {'event': tensor([     0,      1,      2,  ..., 101524, 101528, 101532]),
#  'concept': tensor([     8,      9,     10,  ..., 101569, 101570, 101571]),
#  'event_target': tensor([   54,    87,   269,   335,   419,   461,   715,   754,   801,   827,
#            909,   940,   996,  1044,  1068,  1115,  1156,  1198,  1274,  1308,
#           1348,  1380,  1418,  1476,  1532,  1585,  1691,  1739,  1841,  1868,
#           1904,  1963,  1988,  2020,  2096,  2160,  2195,  2198,  2238,  2266,
#           2288,  2325,  2396,  2429,  2452,  2531,  2597,  2659,  2775,  2858,
#           2885,  2928,  2958,  2985,  3050,  3092,  3130,  3165,  3215,  3259,
#           3323,  3417,  3507,  3545,  3580,  3770,  3949,  4002,  4137,  4272,
#           4341,  4384,  4510,  4671,  4726,  4776,  4846,  4883,  4992,  5079,
#           5113,  5215,  5424,  5529,  5576,  5603,  5741,  5787,  5806,  5896,
#           5970,  6042,  6058,  6110,  6144,  6232,  6297,  6345,  6492,  6526,
# ...

# %%
hg.node_to_graph_mapping
# Out:
# {'event': tensor([     0,      1,      2,  ..., 101524, 101528, 101532]),
#  'concept': tensor([     8,      9,     10,  ..., 101569, 101570, 101571]),
#  'event_target': tensor([   54,    87,   269,   335,   419,   461,   715,   754,   801,   827,
#            909,   940,   996,  1044,  1068,  1115,  1156,  1198,  1274,  1308,
#           1348,  1380,  1418,  1476,  1532,  1585,  1691,  1739,  1841,  1868,
#           1904,  1963,  1988,  2020,  2096,  2160,  2195,  2198,  2238,  2266,
#           2288,  2325,  2396,  2429,  2452,  2531,  2597,  2659,  2775,  2858,
#           2885,  2928,  2958,  2985,  3050,  3092,  3130,  3165,  3215,  3259,
#           3323,  3417,  3507,  3545,  3580,  3770,  3949,  4002,  4137,  4272,
#           4341,  4384,  4510,  4671,  4726,  4776,  4846,  4883,  4992,  5079,
#           5113,  5215,  5424,  5529,  5576,  5603,  5741,  5787,  5806,  5896,
#           5970,  6042,  6058,  6110,  6144,  6232,  6297,  6345,  6492,  6526,
# ...
